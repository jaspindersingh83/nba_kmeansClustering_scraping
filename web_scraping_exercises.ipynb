# %%
import requests
response = requests.get(
  'https://www.kaggle.com/jobs'
)
content=response.content
from bs4 import BeautifulSoup
parser=BeautifulSoup(content,'html.parser')
parser.form
# Out:
# <form action="/account/login" id="signin" method="post"><input id="returnUrl" name="returnUrl" type="hidden" value="https://www.kaggle.com/jobs"/><input data-val="true" data-val-length="The field User name must be a string with a minimum length of 2 and a maximum length of 255." data-val-length-max="255" data-val-length-min="2" data-val-required="The User name field is required." id="UserName" name="UserName" placeholder="Email / username" type="text" value=""/><span class="field-validation-valid" data-valmsg-for="UserName" data-valmsg-replace="true"></span><input data-val="true" data-val-length="The field Password must be a string with a minimum length of 1 and a maximum length of 255." data-val-length-max="255" data-val-length-min="1" data-val-required="The Password field is required." id="Password" name="Password" placeholder="Password" type="password"/><span class="field-validation-valid" data-valmsg-for="Password" data-valmsg-replace="true"></span> <div id="remember-me">
# ...

# %%
r = requests.post("https://www.kaggle.com/account/login", data=dict(
    email="jaspindersingh83",
    password="Bawamano@83"
))
r
# Out:
# <Response [200]>

# %%
response = requests.get(
  'https://www.kaggle.com/jobs'
)
content=response.content
from bs4 import BeautifulSoup
parser=BeautifulSoup(content,'html.parser')
parser
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7 ]><html class="ie ie6 lte7 lte8 lte9"><![endif]-->
# <!--[if IE 7 ]><html class="ie ie7 lte7 lte8 lte9"><![endif]-->
# <!--[if IE 8 ]><html class="ie ie8 lte8 lte9"><![endif]-->
# <!--[if IE 9 ]><html class="ie ie9 lte9"><![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!--><html><!--<![endif]-->
# <head>
# <link href="//fonts.googleapis.com/css?family=Merriweather:400,700|Open+Sans:300,400italic,700italic,400,700" rel="stylesheet" type="text/css">
# <link href="/content/v/1fb55cec3f8f/shared/css/font-awesome.min.css" rel="stylesheet">
# <title>Data Science Jobs Board | Kaggle</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="index, follow" name="robots"/>
# <link href="/content/v/d420a040e581/kaggle/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# ...

# %%
r = requests.post("https://www.upwork.com/ab/account-security/login", data=dict(
    email="jas@salespointinc.com",
    password="Bawamano@83"
))
r.status_code
# Out:
# 403

# %%
response = requests.get(
  'https://www.upwork.com/ab/account-security/login'
)
content=response.content
from bs4 import BeautifulSoup
parser=BeautifulSoup(content,'html.parser')
parser
# Out:
# <html><head><script src="https://www.google.com/recaptcha/api.js"></script> <link href="https://assets.static-upwork.com/components/1.8.4/air.global.1.8.4.min.css" rel="stylesheet">
# <link href="https://assets.static-upwork.com/components/1.8.4/air.components.1.8.4.min.css" rel="stylesheet">
# <link href="https://assets.static-upwork.com/fonts/1.10.0/fonts.gotham.1.10.0.css" rel="stylesheet">
# <link href="https://assets.static-upwork.com/fonts/1.10.0/fonts.air-icons.1.10.0.css" rel="stylesheet">
# <script src="https://assets.static-upwork.com/components/1.8.4/core.1.8.4.min.js"></script>
# <script src="https://assets.static-upwork.com/components/1.8.4/angular-select.1.8.4.min.js"></script>
# <script src="https://assets.static-upwork.com/components/1.8.4/files.1.8.4.min.js"></script>
# <script>
#                         //async font loading
#                         window.onload = function() {
#                         var linkGotham = document.createElement('link');
# ...
